# %% [markdown]
# <a href="https://colab.research.google.com/github/alishermutalov/matplotlib-learning/blob/plt-branch/distribution.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('https://raw.githubusercontent.com/anvarnarz/praktikum_datasets/main/merc.csv')
df = df[(df['year']>=2010) & (df['transmission']!='Other') & (df['fuelType']!='Other')]
df
# Out:
#             model  year   price transmission  mileage fuelType  tax   mpg  \
# 1         S Class  2017   34948    Automatic    27000   Hybrid   20  61.4
# 2        SL CLASS  2016   49948    Automatic     6200   Petrol  555  28.0
# 3         G Class  2016   61948    Automatic    16000   Petrol  325  30.4
# 4         G Class  2016   73948    Automatic     4000   Petrol  325  30.1
# 5        SL CLASS  2011  149948    Automatic     3000   Petrol  570  21.4
# ...           ...   ...     ...          ...      ...      ...  ...   ...
# 13114     C Class  2020   35999    Automatic      500   Diesel  145  55.4
# 13115     B Class  2020   24699    Automatic     2500   Diesel  145  55.4
# 13116   GLC Class  2019   30999    Automatic    11612   Diesel  145  41.5
# 13117   CLS Class  2019   37990    Automatic     2426   Diesel  145  45.6
# 13118     S Class  2019   54999    Automatic     2075   Diesel  145  52.3
#
#        engineSize
# 1             2.1
# 2             5.5
# 3             4.0
# ...

# %%
plt.figure(figsize=(10,5))
sns.histplot(data=df, x='price')
plt.show()

# %%
sns.displot(data=df, x='price', col='transmission', height=5, aspect=2, )
plt.show()

# %%
sns.displot(data=df, x='price', hue='transmission', height=5, aspect=2, multiple='stack')
plt.show()

# %%
sns.displot(data=df, x='price', hue='transmission', height=5, aspect=2)
plt.show()

# %%
sns.displot(data=df, kind='kde', x='price' ,height=5, aspect=2)
plt.show()

# %%
sns.displot(data=df, x='price' , kde=True, height=5, aspect=2)
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.kdeplot(data=df, x='price', hue='transmission', fill=True)
plt.show()

# %%
sns.displot(data=df, x='price', y='year' , kind='kde', height=5, aspect=2)
plt.show()

# %%
sns.displot(data=df, x='price' , kind='ecdf', height=5, aspect=2)
plt.grid(which='both') #'major', 'minor', 'both' qiymatlar berish mumkin
plt.minorticks_on() #setkani kichraytirib beradi (ma'lumotlarni aniqroq tahlil qilish uchun qo'l keladi)
plt.show()

# %%
sns.displot(data=df, x='price' , kind='ecdf', height=5, aspect=2)
plt.grid(which='major') #'major', 'minor', 'both' qiymatlar berish mumkin
plt.minorticks_on() #setkani kichraytirib beradi (ma'lumotlarni aniqroq tahlil qilish uchun qo'l keladi)
plt.show()

# %%
sns.displot(data=df, x='price' , kind='ecdf', height=5, aspect=2)
plt.grid(which='minor') #'major', 'minor', 'both' qiymatlar berish mumkin
plt.minorticks_on() #setkani kichraytirib beradi (ma'lumotlarni aniqroq tahlil qilish uchun qo'l keladi)
plt.show()
